# %%
import GPUtil
from threading import Thread
import time

attrList = [[{'attr':'id','name':'ID'}],
            [{'attr':'temperature','name':'GPU temp.','suffix':'C','transform': lambda x: x,'precision':0},
             {'attr':'load','name':'GPU util.','suffix':'%','transform': lambda x: x*100,'precision':0},
             {'attr':'memoryUtil','name':'Memory util.','suffix':'%','transform': lambda x: x*100,'precision':0}],
            [{'attr':'memoryTotal','name':'Memory total','suffix':'MB','precision':0},
             {'attr':'memoryUsed','name':'Memory used','suffix':'MB','precision':0},
             {'attr':'memoryFree','name':'Memory free','suffix':'MB','precision':0}]]

class Monitor(Thread):
    def __init__(self, delay):
        super(Monitor, self).__init__()
        self.stopped = False
        self.delay = delay # Time between calls to GPUtil
        self.start()

    def run(self):
        while not self.stopped:
#             GPUtil.showUtilization(all=True)
            GPUtil.showUtilization(attrList=attrList)
            time.sleep(self.delay)

    def stop(self):
        self.stopped = True
        
# Instantiate monitor with a 10-second delay between updates
monitor = Monitor(10)

# %%
# Out:
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       59C |       78% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       64C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       65C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       66C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       64C |       78% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       64C |       77% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       65C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       66C |       96% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       67C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       67C |       94% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       67C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       67C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       63C |       79% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |      100% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       59C |       77% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       94% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       63C |       96% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       64C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       65C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       66C |       95% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       66C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       67C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       67C |       97% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       56C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       47C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       44C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15883MB |       247MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          98% ||      16130MB |     15885MB |       245MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          21% ||      16130MB |      3329MB |     12801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          28% ||      16130MB |      4440MB |     11690MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       38C |        0% |          30% ||      16130MB |      4772MB |     11358MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# ...
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |          89% ||      16130MB |     14362MB |      1768MB |

# %%
monitor.stop()
