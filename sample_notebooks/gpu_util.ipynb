# %%
import GPUtil
from threading import Thread
import time

attrList = [[{'attr':'id','name':'ID'}],
            [{'attr':'temperature','name':'GPU temp.','suffix':'C','transform': lambda x: x,'precision':0},
             {'attr':'load','name':'GPU util.','suffix':'%','transform': lambda x: x*100,'precision':0},
             {'attr':'memoryUtil','name':'Memory util.','suffix':'%','transform': lambda x: x*100,'precision':0}],
            [{'attr':'memoryTotal','name':'Memory total','suffix':'MB','precision':0},
             {'attr':'memoryUsed','name':'Memory used','suffix':'MB','precision':0},
             {'attr':'memoryFree','name':'Memory free','suffix':'MB','precision':0}]]

class Monitor(Thread):
    def __init__(self, delay):
        super(Monitor, self).__init__()
        self.stopped = False
        self.delay = delay # Time between calls to GPUtil
        self.start()

    def run(self):
        while not self.stopped:
#             GPUtil.showUtilization(all=True)
            GPUtil.showUtilization(attrList=attrList)
            time.sleep(self.delay)

    def stop(self):
        self.stopped = True
        
# Instantiate monitor with a 10-second delay between updates
monitor = Monitor(10)

# %%
import torch
torch.cuda.empty_cache()
# Out:
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       73C |       66% |          95% ||      16130MB |     15329MB |       801MB |

# %%
# monitor.stop()
# Out:
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       73C |       62% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       74C |       72% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       73C |       93% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       73C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       72C |       88% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       76C |       98% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       94% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       98% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       75C |       97% |          95% ||      16130MB |     15329MB |       801MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       68C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       64C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       60C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       59C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          34% ||      16130MB |      5453MB |     10677MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       56C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       56C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       55C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       56C |        0% |          10% ||      16130MB |      1633MB |     14497MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       56C |        0% |          10% ||      16130MB |      1633MB |     14497MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          10% ||      16130MB |      1633MB |     14497MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          10% ||      16130MB |      1633MB |     14497MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          10% ||      16130MB |      1633MB |     14497MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          10% ||      16130MB |      1633MB |     14497MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          10% ||      16130MB |      1633MB |     14497MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          13% ||      16130MB |      2173MB |     13957MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       56C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       55C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        9% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          17% ||      16130MB |      2681MB |     13449MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       47C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       46C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       44C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       44C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       44C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       44C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          11% ||      16130MB |      1723MB |     14407MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          13% ||      16130MB |      2173MB |     13957MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |       56% |          89% ||      16130MB |     14323MB |      1807MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# ...
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       39C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       40C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |           0% ||      16130MB |        10MB |     16120MB |
