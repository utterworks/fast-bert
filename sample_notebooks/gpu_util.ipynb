# %%
import GPUtil
from threading import Thread
import time

attrList = [[{'attr':'id','name':'ID'}],
            [{'attr':'temperature','name':'GPU temp.','suffix':'C','transform': lambda x: x,'precision':0},
             {'attr':'load','name':'GPU util.','suffix':'%','transform': lambda x: x*100,'precision':0},
             {'attr':'memoryUtil','name':'Memory util.','suffix':'%','transform': lambda x: x*100,'precision':0}],
            [{'attr':'memoryTotal','name':'Memory total','suffix':'MB','precision':0},
             {'attr':'memoryUsed','name':'Memory used','suffix':'MB','precision':0},
             {'attr':'memoryFree','name':'Memory free','suffix':'MB','precision':0}]]

class Monitor(Thread):
    def __init__(self, delay):
        super(Monitor, self).__init__()
        self.stopped = False
        self.delay = delay # Time between calls to GPUtil
        self.start()

    def run(self):
        while not self.stopped:
#             GPUtil.showUtilization(all=True)
            GPUtil.showUtilization(attrList=attrList)
            time.sleep(self.delay)

    def stop(self):
        self.stopped = True
        
# Instantiate monitor with a 10-second delay between updates
monitor = Monitor(10)

# %%
# monitor.stop()
# Out:
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |           0% ||      16130MB |         0MB |     16130MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |           0% ||      16130MB |         0MB |     16130MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       47C |        0% |           0% ||      16130MB |         0MB |     16130MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       47C |        9% |           4% ||      16130MB |       721MB |     15409MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |       63% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |       61% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |       67% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |       70% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |       55% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       54C |       62% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |       74% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |       53% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |       60% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       59C |       66% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       59C |       59% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |       61% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |       60% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       57C |       61% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |       61% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |       57% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       58C |       57% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       59C |       55% |          34% ||      16130MB |      5441MB |     10689MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       91% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       66% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       64% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       67% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       65% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       66% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       68% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       74% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       74% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       63C |       64% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       61% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       63C |       58% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       53% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       56% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       62C |       60% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       63% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       55% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       58% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       62% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       61C |       74% |          34% ||      16130MB |      5489MB |     10641MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       65C |       89% |          34% ||      16130MB |      5491MB |     10639MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       65C |       88% |          34% ||      16130MB |      5491MB |     10639MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       55C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       53C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       52C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       51C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       50C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       49C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       48C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       47C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       46C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       45C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       44C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       44C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       43C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       42C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |
# | ID || GPU temp. | GPU util. | Memory util. || Memory total | Memory used | Memory free |
# ------------------------------------------------------------------------------------------
# |  0 ||       41C |        0% |          14% ||      16130MB |      2225MB |     13905MB |

# %%
monitor.stop()
